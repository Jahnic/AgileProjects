# %%
import pandas as pd
import numpy as np
from pprint import pprint
from comet_ml import Experiment
from time import time
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import  TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import json
from joblib import dump

# %%
with open('../data/raw/comet_cred.json') as  f:
    comet_creds = json.load(f)

# %%
train_data = np.load("../data/interim/train_data.npy", allow_pickle=True)
dev_data = np.load("../data/interim/dev_data.npy", allow_pickle=True)
save_model_path = '../models/sklearn_model.pkl'
n_experiments = 20

# %%
def convert_category_to_number(category):
    if category == "positive":
        return 2
    elif category == "negative":
        return 0
    else: return 1

# %%
all_data = np.concatenate([train_data, dev_data])
all_labels = [convert_category_to_number(x) for x in all_data[:,1]]
all_text = all_data[:, 10]

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', RandomForestClassifier())
])

parameters = {
    'tfidf__max_df': (0.975, 0.99),
    'tfidf__min_df': (0.025, 0.01),
    'tfidf__stop_words': ('english', None),
    'tfidf__max_features': (50000, 60000),
    'tfidf__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'tfidf__norm': ('l1', 'l2'),
    'clf__n_estimators': (4000, 5000, 6000),
    'clf__max_depth': (None, 2),
    'clf__min_samples_split': (2, 3)
}

random_search = RandomizedSearchCV(pipeline, parameters, n_iter=n_experiments, verbose=1, cv=5,
                                    scoring="f1_weighted", random_state=42)

# %%
print("Performing random search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
random_search.fit(all_text, all_labels)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % random_search.best_score_)
print("Best parameters set:")
best_parameters = random_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing random search...
# pipeline: ['tfidf', 'clf']
# parameters:
# {'clf__max_depth': (None, 2),
#  'clf__min_samples_split': (2, 3),
#  'clf__n_estimators': (4000, 5000, 6000),
#  'tfidf__max_df': (0.975, 0.99),
#  'tfidf__max_features': (50000, 60000),
#  'tfidf__min_df': (0.025, 0.01),
#  'tfidf__ngram_range': ((1, 1), (1, 2)),
#  'tfidf__norm': ('l1', 'l2'),
#  'tfidf__stop_words': ('english', None)}
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# done in 14256.547s
#
# Best score: 0.735
# Best parameters set:
# 	clf__max_depth: None
# 	clf__min_samples_split: 3
# 	clf__n_estimators: 5000
# 	tfidf__max_df: 0.975
# 	tfidf__max_features: 50000
# 	tfidf__min_df: 0.01
# 	tfidf__ngram_range: (1, 1)
# 	tfidf__norm: 'l1'
# 	tfidf__stop_words: None

# %%
for i in range(len(random_search.cv_results_['params'])):
    experiment = Experiment(api_key=comet_creds["api_key"], project_name=comet_creds["project_name"],
                        workspace=comet_creds["workspace"])
    for k,v in random_search.cv_results_.items():
        if k == "params":
            experiment.log_parameters(v[i])
        else:
            experiment.log_metric(k,v[i])
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/0d0a19f0b08c4db6baf6d912cc8e095f
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/0d0a19f0b08c4db6baf6d912cc8e095f
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 14.65947904586792
# COMET INFO:     mean_score_time              : 1.3476103782653808
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.8590277418834806
# COMET INFO:     std_score_time               : 0.05164284672731411
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/381a7c2ad72549e5bb5391b6c322b3d3
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/381a7c2ad72549e5bb5391b6c322b3d3
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 185.93515801429749
# COMET INFO:     mean_score_time              : 3.6352008819580077
# COMET INFO:     mean_test_score              : 0.6514071726503565
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 6
# COMET INFO:     split0_test_score            : 0.6462117876305362
# COMET INFO:     split1_test_score            : 0.656286472719521
# COMET INFO:     split2_test_score            : 0.6615999941712903
# COMET INFO:     split3_test_score            : 0.6470702441728826
# COMET INFO:     split4_test_score            : 0.6458673645575527
# COMET INFO:     std_fit_time                 : 3.6063642363517276
# COMET INFO:     std_score_time               : 0.2289939666179061
# COMET INFO:     std_test_score               : 0.006390487110550378
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/8e9fd06f5861488d9cdeb7fabaca1b6a
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/8e9fd06f5861488d9cdeb7fabaca1b6a
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 10.308806991577148
# COMET INFO:     mean_score_time              : 0.9428636074066162
# COMET INFO:     mean_test_score              : 0.48137849040394637
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 12
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.48198798864974507
# COMET INFO:     std_fit_time                 : 0.13821219971781307
# COMET INFO:     std_score_time               : 0.007390517972169827
# COMET INFO:     std_test_score               : 0.00032544783456684405
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/778c293559c640fc9ca0435840911d84
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/778c293559c640fc9ca0435840911d84
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 12.75280466079712
# COMET INFO:     mean_score_time              : 1.1686270713806153
# COMET INFO:     mean_test_score              : 0.48137849040394637
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l2
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 12
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.48198798864974507
# COMET INFO:     std_fit_time                 : 0.14704466343394543
# COMET INFO:     std_score_time               : 0.01554582495708865
# COMET INFO:     std_test_score               : 0.00032544783456684405
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l2
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/c9b9fa8853d049c7b79d83b5f01552d9
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/c9b9fa8853d049c7b79d83b5f01552d9
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 15.664627170562744
# COMET INFO:     mean_score_time              : 1.2453013420104981
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.08012184683517333
# COMET INFO:     std_score_time               : 0.00539092477711273
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/6caf39a9aa564f9d8c987bc0d4d481f4
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/6caf39a9aa564f9d8c987bc0d4d481f4
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 199.98338289260863
# COMET INFO:     mean_score_time              : 3.2881071090698244
# COMET INFO:     mean_test_score              : 0.7053115645448418
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 5
# COMET INFO:     split0_test_score            : 0.7054193405020476
# COMET INFO:     split1_test_score            : 0.7010578341341946
# COMET INFO:     split2_test_score            : 0.7122868405885024
# COMET INFO:     split3_test_score            : 0.70042943406438
# COMET INFO:     split4_test_score            : 0.7073643734350845
# COMET INFO:     std_fit_time                 : 2.4059837938046034
# COMET INFO:     std_score_time               : 0.030334283747989684
# COMET INFO:     std_test_score               : 0.00435452721467661
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/c0111b5c420b43979438ddcc2e58a95b
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/c0111b5c420b43979438ddcc2e58a95b
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 428.1770541667938
# COMET INFO:     mean_score_time              : 3.7163039684295653
# COMET INFO:     mean_test_score              : 0.7080003425223959
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 3
# COMET INFO:     split0_test_score            : 0.7135977915837013
# COMET INFO:     split1_test_score            : 0.7088785578984927
# COMET INFO:     split2_test_score            : 0.719103929086388
# COMET INFO:     split3_test_score            : 0.6975967024203377
# COMET INFO:     split4_test_score            : 0.7008247316230599
# COMET INFO:     std_fit_time                 : 2.546892025433283
# COMET INFO:     std_score_time               : 0.0326523289276996
# COMET INFO:     std_test_score               : 0.007938733551097563
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/83a7658c684f4dfeabe452a7820e2d80
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/83a7658c684f4dfeabe452a7820e2d80
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 183.1966399669647
# COMET INFO:     mean_score_time              : 3.545129728317261
# COMET INFO:     mean_test_score              : 0.6507333012330191
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 8
# COMET INFO:     split0_test_score            : 0.6456439108323568
# COMET INFO:     split1_test_score            : 0.654924611889936
# COMET INFO:     split2_test_score            : 0.6580898009155912
# COMET INFO:     split3_test_score            : 0.6484805744273412
# COMET INFO:     split4_test_score            : 0.6465276080998708
# COMET INFO:     std_fit_time                 : 5.414332994771954
# COMET INFO:     std_score_time               : 0.17468561683749997
# COMET INFO:     std_test_score               : 0.004906112514895127
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/f53c497f83b84d94bc01d9de8468cca3
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/f53c497f83b84d94bc01d9de8468cca3
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 15.421927356719971
# COMET INFO:     mean_score_time              : 1.428615427017212
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.0814335783042181
# COMET INFO:     std_score_time               : 0.006381048032675455
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/874590409a154adc871467185c49cc3d
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/874590409a154adc871467185c49cc3d
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 192.73350257873534
# COMET INFO:     mean_score_time              : 3.7239892959594725
# COMET INFO:     mean_test_score              : 0.6501254408339037
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 10
# COMET INFO:     split0_test_score            : 0.6464178253566527
# COMET INFO:     split1_test_score            : 0.6544162282070796
# COMET INFO:     split2_test_score            : 0.6583066987939701
# COMET INFO:     split3_test_score            : 0.6473526914251099
# COMET INFO:     split4_test_score            : 0.644133760386706
# COMET INFO:     std_fit_time                 : 2.6998233151616633
# COMET INFO:     std_score_time               : 0.09769794466460331
# COMET INFO:     std_test_score               : 0.005341884021268222
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/d98a912a9c3b44fd99662c67bcc2464c
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/d98a912a9c3b44fd99662c67bcc2464c
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 15.676026964187622
# COMET INFO:     mean_score_time              : 1.245043897628784
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l2
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.15806519279178266
# COMET INFO:     std_score_time               : 0.007571527486803798
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l2
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/5c08b8bfb113454a9106194225a5eaf8
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/5c08b8bfb113454a9106194225a5eaf8
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 123.52273387908936
# COMET INFO:     mean_score_time              : 2.4124124526977537
# COMET INFO:     mean_test_score              : 0.6508094457775596
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 7
# COMET INFO:     split0_test_score            : 0.6470661739316969
# COMET INFO:     split1_test_score            : 0.6561177493365881
# COMET INFO:     split2_test_score            : 0.65932507559807
# COMET INFO:     split3_test_score            : 0.6468312628457
# COMET INFO:     split4_test_score            : 0.6447069671757428
# COMET INFO:     std_fit_time                 : 1.8018242399448017
# COMET INFO:     std_score_time               : 0.11311549670457235
# COMET INFO:     std_test_score               : 0.005792621281453825
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/fdf54b6a578744f5907ba36ba9441e9d
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/fdf54b6a578744f5907ba36ba9441e9d
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 327.432745552063
# COMET INFO:     mean_score_time              : 3.0015565395355224
# COMET INFO:     mean_test_score              : 0.7098143734146847
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l2
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 2
# COMET INFO:     split0_test_score            : 0.7201006564828226
# COMET INFO:     split1_test_score            : 0.7095544882349528
# COMET INFO:     split2_test_score            : 0.7165927378966722
# COMET INFO:     split3_test_score            : 0.6977430817857316
# COMET INFO:     split4_test_score            : 0.7050809026732444
# COMET INFO:     std_fit_time                 : 0.7540491871617857
# COMET INFO:     std_score_time               : 0.037839589169501545
# COMET INFO:     std_test_score               : 0.007999290113084768
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l2
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/f5b19f2bc7914c2a9d083dffb86e41f7
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/f5b19f2bc7914c2a9d083dffb86e41f7
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 398.3513590335846
# COMET INFO:     mean_score_time              : 3.971013641357422
# COMET INFO:     mean_test_score              : 0.7347524446579944
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 1
# COMET INFO:     split0_test_score            : 0.7328871933560787
# COMET INFO:     split1_test_score            : 0.7362397200412423
# COMET INFO:     split2_test_score            : 0.7404524246530244
# COMET INFO:     split3_test_score            : 0.7349842845099678
# COMET INFO:     split4_test_score            : 0.7291986007296583
# COMET INFO:     std_fit_time                 : 1.5617555107454397
# COMET INFO:     std_score_time               : 0.01371076401182807
# COMET INFO:     std_test_score               : 0.0037169841141962154
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/e5ae5eadbe4a4e4bb03422f751fbe3d3
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/e5ae5eadbe4a4e4bb03422f751fbe3d3
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 15.416601514816284
# COMET INFO:     mean_score_time              : 1.432981300354004
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.049511917848731636
# COMET INFO:     std_score_time               : 0.02227193362667334
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (30 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/db4998acce0e4e949a6ba078cdee7276
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/db4998acce0e4e949a6ba078cdee7276
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 184.7847680568695
# COMET INFO:     mean_score_time              : 3.5835218906402586
# COMET INFO:     mean_test_score              : 0.6503239817799953
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 6000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 9
# COMET INFO:     split0_test_score            : 0.6454018748498155
# COMET INFO:     split1_test_score            : 0.6560166687349909
# COMET INFO:     split2_test_score            : 0.6574171716112807
# COMET INFO:     split3_test_score            : 0.6484433982496041
# COMET INFO:     split4_test_score            : 0.644340795454285
# COMET INFO:     std_fit_time                 : 2.796636258819199
# COMET INFO:     std_score_time               : 0.12473088619368058
# COMET INFO:     std_test_score               : 0.005408923671217707
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 6000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/cfa793f2dbe2465a86369229e652fd6a
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/cfa793f2dbe2465a86369229e652fd6a
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 16.974832820892335
# COMET INFO:     mean_score_time              : 1.2541785717010498
# COMET INFO:     mean_test_score              : 0.48141479025188944
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.99
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 11
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.48216948788946007
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.13908199291532872
# COMET INFO:     std_score_time               : 0.026647601011048107
# COMET INFO:     std_test_score               : 0.0003942542278213634
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.99
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/c715e026de1c4e53b190783dafbe8154
#
# COMET WARNING: Cannot safely convert (1, 1) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/c715e026de1c4e53b190783dafbe8154
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 15.675584697723389
# COMET INFO:     mean_score_time              : 1.2489980220794679
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 2
# COMET INFO:     param_clf__n_estimators      : 5000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 50000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 1)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.10475333248227413
# COMET INFO:     std_score_time               : 0.005633060219768084
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 2
# COMET INFO:     clf__n_estimators      : 5000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 50000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 1)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/ab01fa5195734d2f877967c00005cb84
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/ab01fa5195734d2f877967c00005cb84
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 10.57558078765869
# COMET INFO:     mean_score_time              : 0.9936769485473633
# COMET INFO:     mean_test_score              : 0.48124086048283166
# COMET INFO:     param_clf__max_depth         : 2
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.01
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : english
# COMET INFO:     rank_test_score              : 14
# COMET INFO:     split0_test_score            : 0.4810049462374732
# COMET INFO:     split1_test_score            : 0.4812998390441713
# COMET INFO:     split2_test_score            : 0.4812998390441713
# COMET INFO:     split3_test_score            : 0.4812998390441713
# COMET INFO:     split4_test_score            : 0.4812998390441713
# COMET INFO:     std_fit_time                 : 0.08261396847754339
# COMET INFO:     std_score_time               : 0.02187904919249146
# COMET INFO:     std_test_score               : 0.00011795712267923531
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 2
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.01
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : english
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     os packages              : 1
# COMET INFO: ---------------------------
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/jahnic/general/312957eda19d464f8cba57021d499093
#
# COMET WARNING: Cannot safely convert (1, 2) object to a scalar value, using its string representation for logging.

# %%
dump(random_search.best_estimator_, save_model_path)
# Out:
# ['../models/sklearn_model.pkl']

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/jahnic/general/312957eda19d464f8cba57021d499093
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time                : 325.49981050491334
# COMET INFO:     mean_score_time              : 3.0371742725372313
# COMET INFO:     mean_test_score              : 0.7068271015822272
# COMET INFO:     param_clf__max_depth         : 1
# COMET INFO:     param_clf__min_samples_split : 3
# COMET INFO:     param_clf__n_estimators      : 4000
# COMET INFO:     param_tfidf__max_df          : 0.975
# COMET INFO:     param_tfidf__max_features    : 60000
# COMET INFO:     param_tfidf__min_df          : 0.025
# COMET INFO:     param_tfidf__ngram_range     : (1, 2)
# COMET INFO:     param_tfidf__norm            : l1
# COMET INFO:     param_tfidf__stop_words      : 1
# COMET INFO:     rank_test_score              : 4
# COMET INFO:     split0_test_score            : 0.7128179101497574
# COMET INFO:     split1_test_score            : 0.7052826974693553
# COMET INFO:     split2_test_score            : 0.7174028623284043
# COMET INFO:     split3_test_score            : 0.702389563690107
# COMET INFO:     split4_test_score            : 0.6962424742735114
# COMET INFO:     std_fit_time                 : 1.0366041273158875
# COMET INFO:     std_score_time               : 0.04152366396611188
# COMET INFO:     std_test_score               : 0.007507965963234584
# COMET INFO:   Parameters:
# COMET INFO:     clf__max_depth         : 1
# COMET INFO:     clf__min_samples_split : 3
# COMET INFO:     clf__n_estimators      : 4000
# COMET INFO:     tfidf__max_df          : 0.975
# COMET INFO:     tfidf__max_features    : 60000
# COMET INFO:     tfidf__min_df          : 0.025
# COMET INFO:     tfidf__ngram_range     : (1, 2)
# COMET INFO:     tfidf__norm            : l1
# COMET INFO:     tfidf__stop_words      : 1
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: Still uploading 2 file(s)
